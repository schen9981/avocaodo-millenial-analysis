# %% [markdown]
# ## This script joing city level demographic & avocado data

# %%
import sqlite3
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.tools import eval_measures

# %%
# Create connection to database
conn = sqlite3.connect('../data/db/avocado_project.db')
c = conn.cursor()
# Print out tables in database
list_tables_cmd = "SELECT name FROM sqlite_master WHERE type='table';"
c.execute(list_tables_cmd)
conn.commit()

for row in c:
  print(row)
# Out:
# ('demographic',)
# ('hab2016_region',)
# ('hab2017_region',)
# ('hab2018_region',)
# ('joined_data',)
# ('millenial_percentages',)
# ('hab2016_citystate',)
# ('hab2017_citystate',)
# ('hab2018_citystate',)

# %%
# Load all tables into dataframe
query1 = "SELECT * FROM millenial_percentages"
mill_df = pd.read_sql(query1, conn)

# query2 = "SELECT * FROM hab2016_citystate"
# hab2016_df = pd.read_sql(query2, conn)
# hab2016_df['year'] = 2016

query3 = "SELECT * FROM hab2017_citystate"
hab2017_df = pd.read_sql(query3, conn)
hab2017_df['year'] = 2017

# query4 = "SELECT * FROM hab2018_citystate"
# hab2018_df = pd.read_sql(query4, conn)
# hab2018_df['year'] = 2018

# %%
to_remove = ["California", "Northern New England", "Roanoke", "South Carolina", "West Tex/New Mexico"]
mill_df = mill_df[~mill_df["name"].isin(to_remove)]
mill_df
# Out:
#                     name percent_millenial
# 0                 Albany                22
# 1                Atlanta                26
# 2   Baltimore/Washington                23
# 3                  Boise                26
# 4                 Boston                23
# 5      Buffalo/Rochester              26.1
# 7              Charlotte                25
# 8                Chicago                24
# 9      Cincinnati/Dayton                26
# 10              Columbus                29
# 11      Dallas/Ft. Worth                28
# 12                Denver                29
# 13               Detroit                22
# 14          Grand Rapids                27
# 15   Harrisburg/Scranton                23
# 16  Hartford/Springfield                21
# 17               Houston                28
# 18          Indianapolis                27
# 19          Jacksonville                25
# 20             Las Vegas                26
# 21           Los Angeles                23
# ...

# %%
# hab2017_df
# hab2017_df.to_excel("output.xlsx")
